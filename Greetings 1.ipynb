# %% [markdown]
# # Greetings!
#
# ##Just click the run code  buttons below to get a seasonal greeting from Python ...run

# %%
#@title First: click RUN to load some stuff
#from google.colab import files
#from IPython.display import Image

#uploaded = files.upload()

import letters

Image('holly.jpg')

# %%
#@title Second: click RUN to see the message
banner="MERRY PYTHONDAY TO EVERYONE".split()
for word in banner:
   for y in range(7):
      row=" "*12 # a litte indent for readability
      for letter in word:
          row=row+bigletters_d[letter][y]+" "
      print(row.replace("*","\u25ab"))
      #print(row)
   print()

# Note use of Unicode character u250.
# More examples here: https://www.compart.com/en/unicode/category

# %% [markdown]
# Now get the files to do this here.
